# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('../')

# %%
import os
# we need access to Ian's code
sys.path.append('../../external/ian/')
import figure5

# %%
bbox, im, angles, params = figure5.Figure5.angle([True,False,False])

# %%
import cv2

# %%
cv2.imwrite('a.png', im*255)
# Out:
# True

# %%
plt.figure(figsize=(10,10))
imshow(train.load_image(20))

# %%
a = train.load_image(20)
labels = cv2.connectedComponents(a,connectivity=8)
for l in range(max(labels)):
    currentLabel = np.zeros(a.shape)
    currentLabel[labels == l] = 1
    lines = cv2.HoughLines(currentLabel,1,np.pi/180,10)
    lc0 = (lines[0] + math.pi) % (2*math.pi) - math.pi
    lc1 = (lines[1] + math.pi) % (2*math.pi) - math.pi
    print( "Region " + max(lc0,lc1) - min(lc0,lc1) )

# %%
a = train.load_image(20)
# Out:
# [autoreload of numpy failed: Traceback (most recent call last):
#   File "/n/pfister_lab/haehn/ENVS/maskr/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 244, in check
#     superreload(m, reload, self.old_objects)
#   File "/n/pfister_lab/haehn/ENVS/maskr/lib/python3.6/site-packages/IPython/extensions/autoreload.py", line 376, in superreload
#     module = reload(module)
#   File "/n/pfister_lab/haehn/ENVS/maskr/lib/python3.6/imp.py", line 315, in reload
#     return importlib.reload(module)
#   File "/n/pfister_lab/haehn/ENVS/maskr/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 618, in _exec
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/n/pfister_lab/haehn/ENVS/maskr/lib/python3.6/site-packages/numpy/__init__.py", line 167, in <module>
# ...

# %%
import cv2
